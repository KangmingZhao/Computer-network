# %% [markdown]
# ## 滑动窗口和停等协议

# %% [markdown]
# 不同丢包率下的传输时延和吞吐率

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 设置matplotlib支持中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

df_updated = pd.DataFrame({
    '丢包率 (%)': [0, 5, 10, 20, 30],
    '停等协议传送时间 (s)': [18.23, 180.111, 284.256, 472.234, 842.741],
    '滑动窗口协议传送时间 (s)': [16.596, 134.123, 210.241, 454.547, 722.457]
})

plt.figure(figsize=(10, 7))
plt.plot(df_updated['丢包率 (%)'], df_updated['停等协议传送时间 (s)'], marker='o', label='停等协议')
plt.plot(df_updated['丢包率 (%)'], df_updated['滑动窗口协议传送时间 (s)'], marker='o', label='滑动窗口协议')
plt.xlabel('丢包率 (%)')
plt.ylabel('传送时间 (s)')
plt.title('传输时间与丢包率关系图')
plt.legend()
plt.grid(True)
plt.savefig('transmission_time_vs_packet_loss_updated_cn.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 设置matplotlib支持中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

df_updated = pd.DataFrame({
    '丢包率 (%)': [0, 5, 10, 20, 30],
    '停等协议吞吐率 (bps)': [102465.8256, 10371.11559, 6571.372284, 3955.564402, 2216.519666],
    '滑动窗口协议吞吐率 (bps)': [112554.3504, 13927.15642, 8884.813143, 4109.480428, 2585.554573]
})

plt.figure(figsize=(10, 7))
plt.plot(df_updated['丢包率 (%)'], df_updated['停等协议吞吐率 (bps)'], marker='o', label='停等协议')
plt.plot(df_updated['丢包率 (%)'], df_updated['滑动窗口协议吞吐率 (bps)'], marker='o', label='滑动窗口协议')
plt.xlabel('丢包率 (%)')
plt.ylabel('吞吐率 (bps)')
plt.title('吞吐率与丢包率关系图')
plt.legend()
plt.grid(True)
plt.savefig('throughput_vs_packet_loss_updated_cn.png')
plt.show()

# %% [markdown]
# ### 路由器时延对传输时间和吞吐率的影响

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 设置matplotlib支持中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 用户提供的最新数据
data = {
    '路由器时延 (ms)': [0, 10, 20, 30],
    '停等协议传送时间 (s)': [18.23, 24.35, 30.12, 33.78],
    '滑动窗口协议传送时间 (s)': [15.13, 22.234, 27.475, 32.234]
}

df = pd.DataFrame(data)

plt.figure(figsize=(10, 7))
plt.plot(df['路由器时延 (ms)'], df['停等协议传送时间 (s)'], marker='o', label='停等协议')
plt.plot(df['路由器时延 (ms)'], df['滑动窗口协议传送时间 (s)'], marker='o', label='滑动窗口协议')
plt.xlabel('路由器时延 (ms)')
plt.ylabel('传送时间 (s)')
plt.title('传送时间与路由器时延关系图')
plt.legend()
plt.grid(True)
plt.savefig('transmission_time_vs_router_delay_cn.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 设置matplotlib支持中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 更新的数据
data = {
    '滑动窗口大小': [2, 4, 8, 16, 32],
    '丢包率0% 传输时间 (s)': [15.99980228, 12.22977472, 10.99978992, 6.99978992, 19.99980228],
    '丢包率5% 传输时间 (s)': [130.9983441, 110.1087743, 102.996577, 110.9963793, 147.9962804],
    '丢包率10% 传输时间 (s)': [282.9974049, 264.2524873, 243.995749, 224.9955884, 300.9952547],
    '丢包率0% 吞吐率 (Byte/s)': [116079.747, 151863.2225, 168844.4064, 265329.8201, 92863.56805],
    '丢包率5% 吞吐率 (Byte/s)': [14177.68303, 16867.43869, 18032.18179, 16732.55481, 12549.32215],
    '丢包率10% 吞吐率 (Byte/s)': [6562.791629, 7028.327411, 7611.825237, 8254.619627, 6170.373024]
}

df = pd.DataFrame(data)

# 绘制传输时间图
plt.figure(figsize=(10, 7))
for loss_rate in [0, 5, 10]:
    plt.plot(df['滑动窗口大小'], df[f'丢包率{loss_rate}% 传输时间 (s)'], marker='o', label=f'丢包率{loss_rate}%')
plt.xlabel('滑动窗口大小')
plt.ylabel('传输时间 (s)')
plt.title('传输时间与滑动窗口大小关系图')
plt.legend()
plt.grid(True)
plt.savefig('transmission_time_vs_window_size_cn.png')
plt.show()

# 绘制吞吐率图
plt.figure(figsize=(10, 7))
for loss_rate in [0, 5, 10]:
    plt.plot(df['滑动窗口大小'], df[f'丢包率{loss_rate}% 吞吐率 (Byte/s)'], marker='o', label=f'丢包率{loss_rate}%')
plt.xlabel('滑动窗口大小')
plt.ylabel('吞吐率 (Byte/s)')
plt.title('吞吐率与滑动窗口大小关系图')
plt.legend()
plt.grid(True)
plt.savefig('throughput_vs_window_size_cn.png')
plt.show()

# %% [markdown]
# ## 滑动窗口

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 设置matplotlib支持中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 更新的数据
data = {
    '丢包率': [0, 0, 0, 0, 0, 5, 5, 5, 5, 5, 10, 10, 10, 10, 10],
    '滑动窗口大小': [2, 4, 8, 16, 32, 2, 4, 8, 16, 32, 2, 4, 8, 16, 32],
    '传送时间 (s)': [14.03854652, 5.995168935, 2.915955672, 3.915955672, 3.038546517, 100.2064898, 77.03104075, 53.04233659, 43.80883125, 86.10015635, 223.5176333, 179.6873673, 153.4534728, 121.6711913, 200.7387603],
    '吞吐率 (Byte/s)': [132303.7252, 309808.1172, 636961.672, 474303.6326, 611263.3096, 18535.2466, 24111.73446, 35016.40613, 42396.74848, 21571.99335, 8309.644178, 10336.57528, 12103.68176, 15265.33916, 9252.582796]
}

df = pd.DataFrame(data)

# 绘制传输时间图
plt.figure(figsize=(10, 7))
for loss_rate in [0, 5, 10]:
    plt.plot(df[df['丢包率'] == loss_rate]['滑动窗口大小'], df[df['丢包率'] == loss_rate]['传送时间 (s)'], marker='o', label=f'丢包率{loss_rate}%')
plt.xlabel('滑动窗口大小')
plt.ylabel('传送时间 (s)')
plt.title('传送时间与滑动窗口大小关系图')
plt.legend()
plt.grid(True)
plt.savefig('se-transmission_time_vs_window_size_updated.png')
plt.show()

# 绘制吞吐率图
plt.figure(figsize=(10, 7))
for loss_rate in [0, 5, 10]:
    plt.plot(df[df['丢包率'] == loss_rate]['滑动窗口大小'], df[df['丢包率'] == loss_rate]['吞吐率 (Byte/s)'], marker='o', label=f'丢包率{loss_rate}%')
plt.xlabel('滑动窗口大小')
plt.ylabel('吞吐率 (Byte/s)')
plt.title('吞吐率与滑动窗口大小关系图')
plt.legend()
plt.grid(True)
plt.savefig('se-throughput_vs_window_size_updated.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 设置matplotlib支持中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 用户提供的最新数据（合并后的数据）
data = {
    '确认类型': ['累积确认', '累积确认', '累积确认', '累积确认', '累积确认', '累积确认', '累积确认', '累积确认', '累积确认', '累积确认',
               '选择确认', '选择确认', '选择确认', '选择确认', '选择确认', '选择确认', '选择确认', '选择确认', '选择确认', '选择确认'],
    '丢包率': [0, 0, 0, 0, 0, 5, 5, 5, 5, 5, 0, 0, 0, 0, 0, 5, 5, 5, 5, 5],
    '滑动窗口大小': [2, 4, 8, 16, 32, 2, 4, 8, 16, 32, 2, 4, 8, 16, 32, 2, 4, 8, 16, 32],
    '吞吐率 (Byte/s)': [132303.7252, 116119.5613, 124521.1531, 109798.8217, 102965.7239,
                     15198.47271, 11753.08339, 7642.092427, 7224.7768, 7032.756155,
                     152303.7252, 136119.5613, 144521.1531, 129798.8217, 122965.7239,
                     16198.47271, 13753.08339, 8242.092427, 7824.7768, 7632.756155],
    '传送时间 (s)': [14.03854652, 15.99516893, 14.91595567, 16.91595567, 18.03854652,
                   122.2064898, 158.0310407, 243.0423366, 257.0808831, 264.1001563,
                   10.03854652, 11.99516893, 10.91595567, 12.91595567, 14.03854652,
                   112.2064898, 148.0310407, 233.0423366, 247.0808831, 254.1001563]
}

df = pd.DataFrame(data)

# 绘制吞吐率对比图
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
for confirmation_type in ['累积确认', '选择确认']:
    for loss_rate in [0, 5]:
        df_filtered = df[(df['确认类型'] == confirmation_type) & (df['丢包率'] == loss_rate)]
        plt.plot(df_filtered['滑动窗口大小'], df_filtered['吞吐率 (Byte/s)'], marker='o', label=f'{confirmation_type} - 丢包率{loss_rate}%')
plt.xlabel('滑动窗口大小')
plt.ylabel('吞吐率 (Byte/s)')
plt.title('吞吐率对比')
plt.legend()
plt.grid(True)

# 绘制传输时间对比图
plt.subplot(1, 2, 2)
for confirmation_type in ['累积确认', '选择确认']:
    for loss_rate in [0, 5]:
        df_filtered = df[(df['确认类型'] == confirmation_type) & (df['丢包率'] == loss_rate)]
        plt.plot(df_filtered['滑动窗口大小'], df_filtered['传送时间 (s)'], marker='o', label=f'{confirmation_type} - 丢包率{loss_rate}%')
plt.xlabel('滑动窗口大小')
plt.ylabel('传送时间 (s)')
plt.title('传送时间对比')
plt.legend()
plt.grid(True)

# 调整子图布局
plt.tight_layout()

# 显示图表
plt.show()
